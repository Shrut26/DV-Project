# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing Kaggle datasets

# %%
artists = pd.read_csv('/content/drive/MyDrive/DV Project/artists.csv')
tracks = pd.read_csv('/content/drive/MyDrive/DV Project/tracks.csv')

# %%
artists
# Out:
#                              id  followers            genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                []
# ...                         ...        ...               ...
# 1162090  3cOzi726Iav1toV2LRVEjp     4831.0  ['black comedy']
# 1162091  6LogY6VMM3jgAE6fPzXeMl       46.0                []
# 1162092  19boQkDEIay9GaVAWkUhTa      257.0                []
# 1162093  5nvjpU3Y7L6Hpe54QuvDjy     2357.0  ['black comedy']
# 1162094  2bP2cNhNBdKXHC6AnqgyVp       40.0    ['new comedy']
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# ...

# %%
tracks
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
tracks.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %%
tracks.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
tracks.dropna(inplace=True)
tracks.isnull().sum()
# Out:
# id                  0
# name                0
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# id_artists          0
# release_date        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
tracks.drop(columns = ['id'], inplace = True)
tracks
# Out:
#                                        name  popularity  duration_ms  \
# 0                                     Carve           6       126903
# 1       Capítulo 2.16 - Banquero Anarquista           0        98200
# 2        Vivo para Quererte - Remasterizado           0       181640
# 3             El Prisionero - Remasterizado           0       176907
# 4                       Lady of the Evening           0       163080
# ...                                     ...         ...          ...
# 586667                                  云与海          50       258267
# 586668                                blind          72       153293
# 586669            What They'll Say About Us          70       187601
# 586670                      A Day At A Time          58       142003
# 586671                     Mar de Emociones          38       214360
#
#         explicit                          artists  \
# 0              0                          ['Uli']
# ...

# %%
tracks['duration_ms'] = tracks['duration_ms'] / (60000)

# %%
tracks.rename(columns = {'duration_ms' : 'duration_min'}, inplace = True)
tracks
# Out:
#                                        name  popularity  duration_min  \
# 0                                     Carve           6      2.115050
# 1       Capítulo 2.16 - Banquero Anarquista           0      1.636667
# 2        Vivo para Quererte - Remasterizado           0      3.027333
# 3             El Prisionero - Remasterizado           0      2.948450
# 4                       Lady of the Evening           0      2.718000
# ...                                     ...         ...           ...
# 586667                                  云与海          50      4.304450
# 586668                                blind          72      2.554883
# 586669            What They'll Say About Us          70      3.126683
# 586670                      A Day At A Time          58      2.366717
# 586671                     Mar de Emociones          38      3.572667
#
#         explicit                          artists  \
# 0              0                          ['Uli']
# ...

# %%
type(tracks['release_date'])
# Out:
# pandas.core.series.Series

# %%
tracks[['year', 'month', 'day']] = tracks['release_date'].str.split('-', expand=True)
tracks.drop(columns = ['release_date', 'day'], inplace = True)
tracks
# Out:
#                                        name  popularity  duration_min  \
# 0                                     Carve           6      2.115050
# 1       Capítulo 2.16 - Banquero Anarquista           0      1.636667
# 2        Vivo para Quererte - Remasterizado           0      3.027333
# 3             El Prisionero - Remasterizado           0      2.948450
# 4                       Lady of the Evening           0      2.718000
# ...                                     ...         ...           ...
# 586667                                  云与海          50      4.304450
# 586668                                blind          72      2.554883
# 586669            What They'll Say About Us          70      3.126683
# 586670                      A Day At A Time          58      2.366717
# 586671                     Mar de Emociones          38      3.572667
#
#         explicit                          artists  \
# 0              0                          ['Uli']
# ...

# %%
tracks.isnull().sum()
# Out:
# name                     0
# popularity               0
# duration_min             0
# explicit                 0
# artists                  0
# id_artists               0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# time_signature           0
# year                     0
# month               136489
# dtype: int64

# %%
tracks.drop(columns = ['month'], inplace = True)
tracks
# Out:
#                                        name  popularity  duration_min  \
# 0                                     Carve           6      2.115050
# 1       Capítulo 2.16 - Banquero Anarquista           0      1.636667
# 2        Vivo para Quererte - Remasterizado           0      3.027333
# 3             El Prisionero - Remasterizado           0      2.948450
# 4                       Lady of the Evening           0      2.718000
# ...                                     ...         ...           ...
# 586667                                  云与海          50      4.304450
# 586668                                blind          72      2.554883
# 586669            What They'll Say About Us          70      3.126683
# 586670                      A Day At A Time          58      2.366717
# 586671                     Mar de Emociones          38      3.572667
#
#         explicit                          artists  \
# 0              0                          ['Uli']
# ...

# %%
mx = 0
for ids in tracks['id_artists']:
  mx = max(mx, len(ids))
mx
# Out:
# 1508

# %%
tracks['artists'].unique()
# Out:
# array(["['Uli']", "['Fernando Pessoa']", "['Ignacio Corsini']", ...,
#        "['阿YueYue']", "['ROLE MODEL']", "['Gentle Bones', 'Clara Benin']"],
#       dtype=object)

# %%
tracks['year']
# Out:
# 0         1922
# 1         1922
# 2         1922
# 3         1922
# 4         1922
#           ...
# 586667    2020
# 586668    2020
# 586669    2020
# 586670    2021
# 586671    2015
# Name: year, Length: 586601, dtype: object

# %%
sd = pd.read_csv('/content/drive/MyDrive/DV Project/spotify_dataset.csv')
sd
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# 4         5                          5                        1
# ...     ...                        ...                      ...
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# ...

# %%
sd.drop(columns = ['Index'], inplace = True)
sd
# Out:
#       Highest Charting Position  Number of Times Charted  \
# 0                             1                        8
# 1                             2                        3
# 2                             1                       11
# 3                             3                        5
# 4                             5                        1
# ...                         ...                      ...
# 1551                        195                        1
# 1552                        196                        1
# 1553                        197                        1
# 1554                        198                        1
# 1555                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# 1      2021-07-23--2021-07-30           STAY (with Justin Bieber)  47,248,719
# ...

# %%
sd.isnull().sum()
# Out:
# Highest Charting Position    0
# Number of Times Charted      0
# Week of Highest Charting     0
# Song Name                    0
# Streams                      0
# Artist                       0
# Artist Followers             0
# Song ID                      0
# Genre                        0
# Release Date                 0
# Weeks Charted                0
# Popularity                   0
# Danceability                 0
# Energy                       0
# Loudness                     0
# Speechiness                  0
# Acousticness                 0
# Liveness                     0
# Tempo                        0
# Duration (ms)                0
# Valence                      0
# Chord                        0
# dtype: int64

# %%
sd[['year', 'month', 'day']] = sd['Release Date'].str.split('-', expand=True)
sd.drop(columns = ['Release Date', 'day', 'month'], inplace = True)
sd
# Out:
#       Highest Charting Position  Number of Times Charted  \
# 0                             1                        8
# 1                             2                        3
# 2                             1                       11
# 3                             3                        5
# 4                             5                        1
# ...                         ...                      ...
# 1551                        195                        1
# 1552                        196                        1
# 1553                        197                        1
# 1554                        198                        1
# 1555                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# 1      2021-07-23--2021-07-30           STAY (with Justin Bieber)  47,248,719
# ...

# %%
sd.columns
# Out:
# Index(['Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Weeks Charted', 'Popularity',
#        'Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness',
#        'Liveness', 'Tempo', 'Duration (ms)', 'Valence', 'Chord', 'year'],
#       dtype='object')

# %%
tracks.to_csv('/content/drive/MyDrive/DV Project/tracks1.csv', index=False)

# %%
artists_filtered = artists[[len(genres) > 0 for genres in artists['genres']]]
artists_filtered
# Out:
#                              id  followers            genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                []
# ...                         ...        ...               ...
# 1162090  3cOzi726Iav1toV2LRVEjp     4831.0  ['black comedy']
# 1162091  6LogY6VMM3jgAE6fPzXeMl       46.0                []
# 1162092  19boQkDEIay9GaVAWkUhTa      257.0                []
# 1162093  5nvjpU3Y7L6Hpe54QuvDjy     2357.0  ['black comedy']
# 1162094  2bP2cNhNBdKXHC6AnqgyVp       40.0    ['new comedy']
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# ...

# %%
i = 0
for genres in artists['genres']:
  print(genres)
  print(type(genres))
  i += 1
  if i == 10:
    break
# Out:
# []
# <class 'str'>
# []
# <class 'str'>
# []
# <class 'str'>
# []
# <class 'str'>
# []
# <class 'str'>
# []
# <class 'str'>
# []
# <class 'str'>
# []
# <class 'str'>
# []
# <class 'str'>
# []
# <class 'str'>

# %%
i = 0
for genres in artists['genres']:
  print(genres)
  print(type(genres))
  i += 1
  if i == 50:
    break

i = 0
for genre in artists['genres']:
  print(len(genre))
  i += 1
  if i == 50:
    break
# Filter out rows with empty genre lists
artists_filtered = artists[artists['genres'].apply(len) > 0]
print(len(artists_filtered))
# Out:
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# <class 'list'>
# ['']
# ...

# %%
print(len(artists_filtered))
# Out:
# 1162095

# %%
artists_filtered.to_csv('/content/drive/MyDrive/DV Project/artists1.csv', index=False)
